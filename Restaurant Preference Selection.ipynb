# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder 
from sklearn import preprocessing

# %%
cuisine = pd.read_csv('chefmozcuisine.csv')
frame =  pd.read_csv('rating_final.csv')
geodata = pd.read_csv('geoplaces2.csv', encoding = 'mbcs')

# %%
frame.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
geodata.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2    El Rincï¿½n de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# ...

# %%
places =  geodata[['placeID', 'name']]
places.head()
# Out:
#    placeID                            name
# 0   134999                 Kiku Cuernavaca
# 1   132825                 puesto de tacos
# 2   135106    El Rincï¿½n de San Francisco
# 3   132667  little pizza Emilio Portes Gil
# 4   132613                   carnitas_mata

# %%
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
rating = pd.DataFrame(frame.groupby('placeID')['rating'].mean())
rating.head()
# Out:
#          rating
# placeID
# 132560     0.50
# 132561     0.75
# 132564     1.25
# 132572     1.00
# 132583     1.00

# %%
location =  geodata[['placeID', 'city']]
location.head()
# Out:
#    placeID             city
# 0   134999       Cuernavaca
# 1   132825           s.l.p.
# 2   135106  San Luis Potosi
# 3   132667        victoria
# 4   132613         victoria

# %%
#convert categorical values in country column to numerical values
geodata['alcohol'].unique()
# Out:
# array(['No_Alcohol_Served', 'Wine-Beer', 'Full_Bar'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()
geodata['alcohol']= label_encoder.fit_transform(geodata['alcohol'])
geodata['alcohol'].unique()
# Out:
# array([1, 2, 0])

# %%
geodata
# No alcohol served = 1 ; Wine-Beer = 2 ; Full Bar = 0
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
geodata['pric'].unique()
# Out:
# array(['medium', 'low', 'high'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()
geodata['price']= label_encoder.fit_transform(geodata['price'])
geodata['price'].unique()
# Out:
# array([2, 1, 0])

# %%
geodata
# medium price = 2 ; low price = 1 ; high price = 0
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
geodata['Rambience'].unique()
# Out:
# array(['familiar', 'quiet'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()
geodata['Rambience']= label_encoder.fit_transform(geodata['Rambience'])
geodata['Rambience'].unique()
# Out:
# array([0, 1])

# %%
geodata
#familiar = 0 ; quiet = 1
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
# Get names of indexes for which column alcohol has value 0
indexNames = geodata[ geodata['alcohol'] == 0 ].index

# %%
#drop values which contain value 0
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
# Get names of indexes for which column alcohol has value 1
indexNames = geodata[ geodata['alcohol'] == 1 ].index

# %%
#drop values which contain value 1
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 2     135106  22.149709 -100.976093
# 5     135040  22.135617 -100.969709
# 7     132875  22.149901 -100.993779
# 11    135069  22.140129 -100.944872
# 12    135065  22.149580 -100.999557
# 13    135076  22.181017 -100.973614
# 16    132854  22.137863 -100.938327
# 18    132856  22.151378 -100.974634
# 21    132862  22.150643 -100.987015
# 28    135045  22.151189 -100.981790
# 33    135050  22.174887 -100.970825
# 36    135057  22.145992 -100.955118
# 38    134992  18.936683  -99.247366
# 40    135041  22.151060 -100.977659
# 45    132925  22.153500 -100.976243
# 46    132955  22.147622 -101.010275
# 47    135059  22.145108 -100.989547
# 48    135001  18.941859  -99.241927
# 52    135066  22.168350 -100.972466
# 57    135074  22.149689 -100.999525
# 74    135047  22.150921 -100.993828
# 82    135048  22.142017 -100.999246
# 88    132773  18.869993  -99.210319
# 91    134987  18.932725  -99.225211
# 97    135027  22.147145 -100.974494
# ...

# %%
# Get names of indexes for which column price has value 0
indexNames = geodata[ geodata['price'] == 0 ].index

# %%
#drop values which contain value 0
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 2     135106  22.149709 -100.976093
# 11    135069  22.140129 -100.944872
# 16    132854  22.137863 -100.938327
# 18    132856  22.151378 -100.974634
# 36    135057  22.145992 -100.955118
# 40    135041  22.151060 -100.977659
# 45    132925  22.153500 -100.976243
# 46    132955  22.147622 -101.010275
# 47    135059  22.145108 -100.989547
# 48    135001  18.941859  -99.241927
# 88    132773  18.869993  -99.210319
# 91    134987  18.932725  -99.225211
# 97    135027  22.147145 -100.974494
# 98    132767  18.882087  -99.163027
# 100   134996  18.923429  -99.216413
# 110   132921  22.150305 -100.989134
# 114   132766  18.910178  -99.231544
# 119   135032  22.152481 -100.973486
# 120   135028  22.146658 -100.987219
# 127   135109  18.921785  -99.235350
#
#                                         the_geom_meter  \
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 11   0101000020957F000038E5D546B74A58C18FD29AD0D29A...
# ...

# %%
# Get names of indexes for which column price has value 1
indexNames = geodata[ geodata['price'] == 1 ].index

# %%
#drop values which contain value 1
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 2     135106  22.149709 -100.976093
# 16    132854  22.137863 -100.938327
# 36    135057  22.145992 -100.955118
# 40    135041  22.151060 -100.977659
# 45    132925  22.153500 -100.976243
# 47    135059  22.145108 -100.989547
# 48    135001  18.941859  -99.241927
# 91    134987  18.932725  -99.225211
# 97    135027  22.147145 -100.974494
# 98    132767  18.882087  -99.163027
# 100   134996  18.923429  -99.216413
# 114   132766  18.910178  -99.231544
# 119   135032  22.152481 -100.973486
# 120   135028  22.146658 -100.987219
# 127   135109  18.921785  -99.235350
#
#                                         the_geom_meter  \
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 16   0101000020957F0000FEC3FB453E4B58C19B4A46361799...
# 36   0101000020957F000095669021894958C182C9C10E669D...
# 40   0101000020957F0000D2002719234858C1CC7A9FC186A3...
# 45   0101000020957F00001EF62687CD4758C1BE336F4EFAA2...
# ...

# %%
# Get names of indexes for which column Rambience has value 1
indexNames = geodata[ geodata['Rambience'] == 1 ].index

# %%
#drop values which contain value 1
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude   longitude  \
# 2     135106  22.149709 -100.976093
# 16    132854  22.137863 -100.938327
# 36    135057  22.145992 -100.955118
# 40    135041  22.151060 -100.977659
# 45    132925  22.153500 -100.976243
# 47    135059  22.145108 -100.989547
# 48    135001  18.941859  -99.241927
# 91    134987  18.932725  -99.225211
# 97    135027  22.147145 -100.974494
# 98    132767  18.882087  -99.163027
# 100   134996  18.923429  -99.216413
# 114   132766  18.910178  -99.231544
# 119   135032  22.152481 -100.973486
# 120   135028  22.146658 -100.987219
#
#                                         the_geom_meter  \
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 16   0101000020957F0000FEC3FB453E4B58C19B4A46361799...
# 36   0101000020957F000095669021894958C182C9C10E669D...
# 40   0101000020957F0000D2002719234858C1CC7A9FC186A3...
# 45   0101000020957F00001EF62687CD4758C1BE336F4EFAA2...
# 47   0101000020957F000005810F19B84858C136805B2745A7...
# ...

# %%
geodata['city'].unique()
# Out:
# array(['San Luis Potosi', '?', 'Cuernavaca', 'Jiutepec'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()
geodata['city']= label_encoder.fit_transform(geodata['city'])
geodata['city'].unique()
# Out:
# array([3, 0, 1, 2])

# %%
geodata
#San Luis Potosi = 3 ; ? = 0 ; Cuernavaca = 1 ; Jiutepec = 2
# Out:
#      placeID   latitude   longitude  \
# 2     135106  22.149709 -100.976093
# 16    132854  22.137863 -100.938327
# 36    135057  22.145992 -100.955118
# 40    135041  22.151060 -100.977659
# 45    132925  22.153500 -100.976243
# 47    135059  22.145108 -100.989547
# 48    135001  18.941859  -99.241927
# 91    134987  18.932725  -99.225211
# 97    135027  22.147145 -100.974494
# 98    132767  18.882087  -99.163027
# 100   134996  18.923429  -99.216413
# 114   132766  18.910178  -99.231544
# 119   135032  22.152481 -100.973486
# 120   135028  22.146658 -100.987219
#
#                                         the_geom_meter  \
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 16   0101000020957F0000FEC3FB453E4B58C19B4A46361799...
# 36   0101000020957F000095669021894958C182C9C10E669D...
# 40   0101000020957F0000D2002719234858C1CC7A9FC186A3...
# 45   0101000020957F00001EF62687CD4758C1BE336F4EFAA2...
# 47   0101000020957F000005810F19B84858C136805B2745A7...
# ...

# %%
# Get names of indexes for which column price has value 0
indexNames = geodata[ geodata['city'] == 0 ].index

# %%
#drop values which contain value 0
geodata.drop(indexNames , inplace=True)

# %%
# Get names of indexes for which column price has value 2
indexNames = geodata[ geodata['city'] == 2 ].index

# %%
#drop values which contain value 2
geodata.drop(indexNames , inplace=True)

# %%
# Get names of indexes for which column price has value 3
indexNames = geodata[ geodata['city'] == 3 ].index

# %%
#drop values which contain value 3
geodata.drop(indexNames , inplace=True)

# %%
geodata
# Out:
#      placeID   latitude  longitude  \
# 48    135001  18.941859 -99.241927
# 91    134987  18.932725 -99.225211
# 100   134996  18.923429 -99.216413
# 114   132766  18.910178 -99.231544
#
#                                         the_geom_meter                  name  \
# 48   0101000020957F0000429477F3B36B5AC1D65C45CAFA56...                  Vips
# 91   0101000020957F0000FE987FAF936D5AC1E1D486215E52...     Chilis Cuernavaca
# 100  0101000020957F0000340233E7476F5AC132844E2A2C50...  Sanborns Casa Piedra
# 114  0101000020957F000043A319BA06715AC1944336987755...                Mikasa
#
#                                             address  city    state country  \
# 48              Emiliano Zapata No. 825 Tlaltenongo     1  Morelos  Mexico
# 91   Rio Mayo Colonia Vista Hermosa Esq. Rio Balsas     1  Morelos  Mexico
# 100                               Lomas del Mirador     1  Morelos  Mexico
# 114                Himno nacional esq. Blvd. Juarez     1  Morelos  Mexico
#
# ...
